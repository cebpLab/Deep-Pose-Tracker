# %% [markdown]
# ## For keypoints

# %%
# training
from ultralytics import YOLO

model = YOLO("yolov8x-pose.pt")
data = "/home/debasish/Documents/YOLOv8/training/pose-detection-with-padding/Worm-Pose-Detector-1024/data.yaml"

model.train(data=data, epochs=1000, save=True, batch=18, val=True, device=[0,1], imgsz=1024, project="runs/pose-final")
# Out:
# Ultralytics 8.3.168 🚀 Python-3.12.7 torch-2.7.1+cu126 CUDA:0 (NVIDIA RTX 4000 SFF Ada Generation, 20024MiB)
#                                                        CUDA:1 (NVIDIA RTX 4000 SFF Ada Generation, 20027MiB)
# ...

# %%
# test
from ultralytics import YOLO

model = YOLO("/home/debasish/Documents/YOLOv8/weights/pose/yolov8x-pose-1024.pt")
data = "/home/debasish/Documents/YOLOv8/training/pose-detection-with-padding/Worm-Pose-Detector-1024/data.yaml"

model.val(data=data, split="test", batch=16, device=[0,1], imgsz=1024)
# Out:
# Ultralytics 8.3.168 🚀 Python-3.12.7 torch-2.7.1+cu126 CUDA:0 (NVIDIA RTX 4000 SFF Ada Generation, 20024MiB)
#                                                        CUDA:1 (NVIDIA RTX 4000 SFF Ada Generation, 20027MiB)
# YOLOv8x-pose summary (fused): 121 layers, 69,457,830 parameters, 0 gradients, 263.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2156.0±671.9 MB/s, size: 32.2 KB)
# val: Scanning /home/debasish/Documents/YOLOv8/training/pose-detection-with-paddi
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        178        339      0.985      0.988      0.989      0.965      0.971      0.973      0.974       0.82
# Speed: 1.7ms preprocess, 61.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/debasish/runs/pose/val9
# ultralytics.utils.metrics.PoseMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %% [markdown]
# ## For detection

# %%
# training
from ultralytics import YOLO

model = YOLO("yolov8l.pt")
data = "/home/debasish/Documents/YOLOv8/training/detect_and_track/worm_tracking_yolo12_832/data.yaml"

model.train(data=data, epochs=1000, save=True, batch=34, val=True, device=[0,1], imgsz=832, project="runs/detect")
# Out:
# Ultralytics 8.3.168 🚀 Python-3.12.7 torch-2.7.1+cu126 CUDA:0 (NVIDIA RTX 4000 SFF Ada Generation, 20024MiB)
#                                                        CUDA:1 (NVIDIA RTX 4000 SFF Ada Generation, 20027MiB)
# ...

# %% [markdown]
# ## Prediction

# %%
from ultralytics import YOLO

model = YOLO("/home/debasish/Documents/YOLOv8/weights/pose/yolov8x-pose-1024.pt")

model.predict("fps_check_multiple.mp4", save=False, imgsz=1024)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1000) /home/debasish/Documents/YOLOv8/fps_check_multiple.mp4: 576x1024 9 worms, 26.2ms
# video 1/1 (frame 2/1000) /home/debasish/Documents/YOLOv8/fps_check_multiple.mp4: 576x1024 9 worms, 26.5ms
# video 1/1 (frame 3/1000) /home/debasish/Documents/YOLOv8/fps_check_multiple.mp4: 576x1024 9 worms, 27.0ms
# video 1/1 (frame 4/1000) /home/debasish/Documents/YOLOv8/fps_check_multiple.mp4: 576x1024 9 worms, 26.6ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8x-pose.pt")

# %%
model.info()
# Out:
# YOLOv8x-pose summary: 224 layers, 69,491,724 parameters, 0 gradients, 264.0 GFLOPs
# (224, 69491724, 0, 263.9618432)
