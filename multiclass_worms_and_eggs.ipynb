# %%
import os
import cv2
import numpy as np
import pandas as pd
from pathlib import Path
from ultralytics import YOLO

# configure
path = '/home/debasish/Documents/YOLOv8/training/worms_and_eggs/worm_and_egg_detection/test/images'

# load model
model = YOLO('/home/debasish/Documents/YOLOv8/weights/worms-and-eggs/worms_and_eggs_yolov8x_768.pt') 
names = model.names 

image_extensions = (".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff") 
image_files = [] 

# create output directory 
output_base_dir = Path("outputs/worms_and_eggs")
output_base_dir.mkdir(parents=True, exist_ok=True)

run_num = len(list(output_base_dir.glob("run*"))) + 1
run_dir = output_base_dir / f"run{run_num}"
run_dir.mkdir(parents=True, exist_ok=True)

# collect images
for root, folders, files in os.walk(path): 
    for file in files: 
        if file.lower().endswith(image_extensions): 
            image_files.append(os.path.join(root, file))

image_files.sort()
print(f"Total images: {len(image_files)}")

# output folder
output_path = run_dir

# convert class mapping to list
if isinstance(names, dict):
    max_id = max(names.keys())
    class_list = [names.get(i, f"class_{i}") for i in range(max_id + 1)]
else:
    class_list = list(names)

# generate distinct colors for classes 
colors = {}
n = len(class_list)

for i in range(n):
    inv_i = n - 1 - i   # invert the class index

    hue = int((150 / n) * inv_i)   
    sat = 100
    val = 200

    color = cv2.cvtColor(
        np.uint8([[[hue, sat, val]]]),
        cv2.COLOR_HSV2BGR
    )[0][0]

    colors[i] = tuple(int(c) for c in color)

# counting
def counter(image_path, draw=True):
    image = cv2.imread(image_path)

    results = model.predict(
        image,
        save=False,
        verbose=False,
        max_det=500,
        iou=0.7)

    # initialize dictionary for all classes
    counts = {name: 0 for name in class_list}

    total_count = 0

    for result in results:
        if result.boxes is None or len(result.boxes) == 0:
            continue

        boxes_xyxy = result.boxes.xyxy.cpu().numpy()
        classes = result.boxes.cls.cpu().numpy().astype(int)

        total_count = len(classes)

        for (xyxy, cls_id) in zip(boxes_xyxy, classes):

            cls_name = class_list[cls_id]
            counts[cls_name] += 1

            if draw:
                x1, y1, x2, y2 = map(int, xyxy)
                color = colors[cls_id]

                # draw bounding boxes
                cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

    # summary text on the image
    if draw:
        summary_y = 20

        for cls_name, c in counts.items():
            if c > 0:
                summary_y += 30

                cv2.putText(
                    image,
                    f"{cls_name}: {c}",
                    (10, summary_y),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (96,255,128),
                    2
                )

        out_name = os.path.splitext(os.path.basename(image_path))[0] + "_counted.png"
        out_path = os.path.join(output_path, out_name)

        cv2.imwrite(out_path, image)

    return counts, total_count

# process images and create CSV
outputs = []

csv_columns = ["filename", "total_count"] + class_list

for i, image_path in enumerate(image_files):

    counts, total = counter(image_path)

    row = {
        "filename": os.path.basename(image_path),
        "total_count": total
    }

    for cls in class_list:
        row[cls] = counts.get(cls, 0)

    outputs.append(row)

    print(
        f"[{i+1}/{len(image_files)}] "
        f"{row['filename']}  "
        f"total={total}  "
        f"{ {k:v for k,v in row.items() if k not in ['filename','total_count'] and v>0} }"
    )

df = pd.DataFrame(outputs, columns=csv_columns)

csv_path = os.path.join(output_path, "counts.csv")

df.to_csv(csv_path, index=False)

print(f"\nSaved CSV to: {csv_path}")
print(f"Outputs saved in: {output_path}")

# %%
# read from the save output

import pandas as pd

df = pd.read_csv("/home/debasish/Documents/YOLOv8/counts.csv")
df.head()
# Out:
#                                             filename  total_count  egg  worm  \
# 0  image039_png.rf.14de7d176951460865f3c1152f4c2c...           15   11     4
# 1  image056_mp4-0000_jpg.rf.f759ca181123efde5048a...           20   13     7
# 2  image056b_mp4-0000_jpg.rf.774444d3bab9edbd6c1b...           13    9     4
# 3  image209_jpg.rf.473aec6a0a16e50c94808a07d638c3...            7    2     5
# 4  image211_jpg.rf.61c46f8eaf1029987fda9cf94281f7...           13    7     6
#
#    egg (manual)  worm (manual)
# 0            10            NaN
# 1            13            NaN
# 2             9            NaN
# 3             2            NaN
# 4             7            NaN

# %%
import numpy as np
import matplotlib.pyplot as plt

y = df["egg"]   # prediction
x = df["egg (manual)"]   # manual

x_min = 0; x_max = 45
y_min = 0; y_max = 45

X = np.arange(x_min-1,x_max,10)
Y = X

plt.figure(figsize=(5,5))
plt.scatter(x,y, alpha=0.5, color='blue', s=80)
plt.plot(X,Y, '--', color="gray",linewidth=3)
plt.xlabel("Manual counting", fontsize=18)
plt.ylabel("Prediction", fontsize=18)
plt.xlim(-3,40)
plt.ylim(-3,40)
plt.tick_params(axis="both", labelsize=14)
plt.show()

# %% [markdown]
# ## Residual plot

# %%
import numpy as np
import matplotlib.pyplot as plt

y = df["egg"]                 # prediction
x = df["egg (manual)"]        # manual

# Residuals
error = y - x

plt.figure(figsize=(5,5))
plt.scatter(x, error, alpha=0.5, color='blue', s=80)
plt.axhline(0, linestyle='--', linewidth=2, color="gray")   # zero error line
plt.ylim(-2.5,2.5)
plt.xlim(-2,40)

plt.xlabel("Manual counting", fontsize=18)
plt.ylabel("Error (Prediction - Manual)", fontsize=18)
plt.tick_params(axis="both", labelsize=14)

plt.show()

# %% [markdown]
# ## Absolute and relative errors

# %%
error = y - x

# Define bins centered around integers
bins = np.arange(error.min()-0.5, error.max()+1.5, 1)

plt.figure(figsize=(5,5))
plt.hist(error, bins=bins, rwidth=0.8, alpha=0.5, color="blue")

plt.xlabel("Error", fontsize=18)
plt.ylabel("Frequency", fontsize=18)
plt.xticks(np.arange(error.min(), error.max()+1, 1))  # integer ticks
plt.tick_params(axis="both", labelsize=14)
plt.axvline(np.mean(error), linestyle='--', linewidth=2, label="Mean error", color="black", alpha=0.7)
plt.ylim(0,30)

plt.legend(fontsize=14)
plt.show()

# %%
mae = np.mean(np.abs(error))
mse = np.mean(error**2)
rmse = np.sqrt(mse)
mape = np.mean(np.abs(error) / (x + 1e-8)) * 100

print(f"MAE: {mae:.3f}")
print(f"RMSE: {rmse:.3f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 0.421
# RMSE: 0.795
# MAPE: 5.56%

# %%
abs_error = np.abs(error)
rel_error = abs_error / (x + 1e-8)   # avoid division by zero

plt.figure(figsize=(5,5))
plt.scatter(x, abs_error, alpha=0.6, s=80)

plt.xlabel("Manual counting", fontsize=18)
plt.ylabel("Absolute Error", fontsize=18)
plt.tick_params(axis="both", labelsize=14)

plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(x, rel_error, alpha=0.6, s=80)

plt.xlabel("Manual counting", fontsize=18)
plt.ylabel("Relative Error", fontsize=18)
plt.tick_params(axis="both", labelsize=14)

plt.show()

# %% [markdown]
# ## Error distribution

# %%
X = np.arange(0, 45, 1)

plt.figure(figsize=(5,5))
plt.scatter(x, y, alpha=0.5, s=80)
plt.plot(X, X, '--', linewidth=3)          # ideal line

# error bands (+/- 2 eggs for example)
plt.plot(X, X+2, ':', linewidth=2)
plt.plot(X, X-2, ':', linewidth=2)

plt.xlabel("Manual counting", fontsize=18)
plt.ylabel("Prediction", fontsize=18)
plt.tick_params(axis="both", labelsize=14)

plt.show()
