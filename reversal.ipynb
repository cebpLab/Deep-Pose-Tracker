# %%
import cv2
import numpy as np
from collections import deque, defaultdict
from ultralytics import YOLO
from pathlib import Path
import csv
import pandas as pd

# model
model = YOLO("/home/debasish/Documents/YOLOv8/weights/pose/yolov8l-pose-1024.pt")

# inputs and outputs
input_path = Path("/home/debasish/Documents/YOLOv8/videos/videos/image002.mp4")
output_base_dir = Path("outputs/reversals")
output_base_dir.mkdir(parents=True, exist_ok=True)

VIDEO_EXTS = [".mp4", ".avi", ".mkv", ".mov"]


# create runs folder to save outputs
def create_run_folder(base_dir):
    run_id = 1
    while (base_dir / f"run{run_id}").exists():
        run_id += 1
    run_dir = base_dir / f"run{run_id}"
    run_dir.mkdir(parents=True, exist_ok=True)
    return run_dir


# getting reversals intervals
def get_intervals(series, frames, fps, min_duration_sec=0.1):
    intervals = []
    start = None

    min_frames = int(min_duration_sec * fps)

    for i in range(len(series)):
        if series.iloc[i] == 1:
            if start is None:
                start = frames.iloc[i]
        else:
            if start is not None:
                end = frames.iloc[i - 1]
                if (end - start + 1) >= min_frames:
                    intervals.append((start, end))
                start = None

    if start is not None:
        end = frames.iloc[-1]
        if (end - start + 1) >= min_frames:
            intervals.append((start, end))

    return intervals


def extract_intervals_per_worm(df, fps, min_duration_sec=0.1):
    frames = df["frame"]
    out = {}

    for col in df.columns:
        if not col.startswith("worm_"):
            continue

        worm_id = int(col.split("_")[1])
        out[worm_id] = get_intervals(df[col], frames, fps, min_duration_sec)

    return out


def clean_framewise(df, fps, min_duration_sec=0.1):
    frames = df["frame"]
    cleaned_df = df.copy()

    for col in df.columns:
        if not col.startswith("worm_"):
            continue

        intervals = get_intervals(df[col], frames, fps, min_duration_sec)

        cleaned_df[col] = 0
        for start, end in intervals:
            cleaned_df.loc[
                (cleaned_df["frame"] >= start) &
                (cleaned_df["frame"] <= end), col] = 1

    return cleaned_df


def save_summary_counts(pred_dict, path):
    rows = []

    for wid, intervals in pred_dict.items():
        rows.append({
            "worm_id": wid,
            "num_reversals": len(intervals)
        })

    df = pd.DataFrame(rows)
    df.to_csv(path, index=False)



# main process function
def process_video(video_path, run_dir):

    video_name = Path(video_path).stem

    output_video = run_dir / f"{video_name}_annotated.mp4"
    framewise_path = run_dir / f"{video_name}_framewise.csv"
    cleaned_path = run_dir / f"{video_name}_cleaned.csv"
    summary_path = run_dir / f"{video_name}_summary.csv"

    cap = cv2.VideoCapture(str(video_path))
    width, height = int(cap.get(3)), int(cap.get(4))
    fps = round(cap.get(cv2.CAP_PROP_FPS)) # or 30

    print(f"Processing: {video_name} | FPS={fps} | Size={width}x{height}")

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(str(output_video), fourcc, fps, (width, height))

    # optimized parameters
    BUFFER_SCALE = 1
    ALPHA = 0.03
    H = 0.7

    BUFFER_SIZE = int(BUFFER_SCALE * fps)

    # buffers
    head_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    tail_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    center_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    length_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))

    directions = defaultdict(lambda: "Unknown")
    prev_directions = defaultdict(lambda: "Unknown")

    frame_count = 0
    framewise_data = []

    yolotrack_to_local = {}
    next_local_id = 0
    all_local_ids = set()

    results_gen = model.track(str(video_path), persist=True, tracker="bytetrack.yaml", stream=True)

    for results in results_gen:
        frame_count += 1
        frame = results.orig_img.copy()

        frame_dict = {
            "frame": frame_count,
            "time": (frame_count - 1) / fps
        }

        for result in results:
            if result.keypoints is None or result.boxes is None or result.boxes.id is None:
                continue

            yolotrack_id = int(result.boxes.id.cpu().numpy()[0])

            if yolotrack_id not in yolotrack_to_local:
                local_id = next_local_id
                yolotrack_to_local[yolotrack_id] = local_id
                next_local_id += 1
            else:
                local_id = yolotrack_to_local[yolotrack_id]

            all_local_ids.add(local_id)

            kpts = result.keypoints.xy.cpu().numpy()[0]
            head, tail = kpts[0], kpts[10]

            box = result.boxes.xyxy.cpu().numpy()[0]
            center = np.array([(box[0]+box[2])/2, (box[1]+box[3])/2])

            head_buffers[local_id].append(head)
            tail_buffers[local_id].append(tail)
            center_buffers[local_id].append(center)

            if len(center_buffers[local_id]) < BUFFER_SIZE:
                frame_dict[f"worm_{local_id}"] = ""  # no detection yet
                continue

            # body vector
            body_vec = np.mean(head_buffers[local_id], axis=0) - np.mean(tail_buffers[local_id], axis=0)
            body_vec /= (np.linalg.norm(body_vec) + 1e-6)

            # body length
            diffs = np.diff(kpts, axis=0)
            L_inst = np.sum(np.linalg.norm(diffs, axis=1))
            length_buffers[local_id].append(L_inst)
            body_length = np.median(length_buffers[local_id])

            D_MIN = ALPHA * body_length

            move_vec = center_buffers[local_id][-1] - center_buffers[local_id][0]
            move_norm = np.linalg.norm(move_vec)

            if move_norm < D_MIN:
                directions[local_id] = "Stationary"
            else:
                move_vec_unit = move_vec / (move_norm + 1e-6)
                dot = np.dot(body_vec, move_vec_unit)

                if dot > H:
                    directions[local_id] = "Forward"
                elif dot < -H:
                    directions[local_id] = "Reverse"
                else:
                    directions[local_id] = prev_directions[local_id]

            prev_directions[local_id] = directions[local_id]

            # framewise binary
            frame_dict[f"worm_{local_id}"] = 1 if directions[local_id] == "Reverse" else 0

            # visualization
            color = (0, 0, 255) if directions[local_id] == "Reverse" else (0, 255, 0)
            cv2.putText(frame,
                        f"ID {local_id} {directions[local_id]}",
                        (int(center[0]), int(center[1])),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # fill missing
        complete_dict = {
            "frame": frame_count,
            "time": (frame_count - 1) / fps
        }
        for wid in sorted(all_local_ids):
            complete_dict[f"worm_{wid}"] = frame_dict.get(f"worm_{wid}", "")

        framewise_data.append(complete_dict)
        out.write(frame)

    cap.release()
    out.release()

    # save raw framewise data
    df = pd.DataFrame(framewise_data)
    df.to_csv(framewise_path, index=False)

    # clean and summary
    cleaned_df = clean_framewise(df, fps, min_duration_sec=0.1)
    cleaned_df.to_csv(cleaned_path, index=False)

    pred_dict = extract_intervals_per_worm(cleaned_df, fps, min_duration_sec=0.1)
    save_summary_counts(pred_dict, summary_path)

    print(output_video)
    print(framewise_path)
    print(cleaned_path)
    print(summary_path)


if input_path.is_file():
    run_dir = create_run_folder(output_base_dir)
    process_video(input_path, run_dir)

elif input_path.is_dir():
    videos = [f for f in input_path.iterdir() if f.suffix.lower() in VIDEO_EXTS]
    for v in videos:
        run_dir = create_run_folder(output_base_dir)
        process_video(v, run_dir)

else:
    print("[ERROR] Invalid input path")
