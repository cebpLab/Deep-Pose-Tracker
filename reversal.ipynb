# %%
import warnings
warnings.filterwarnings("ignore", message="Can't initialize NVML")

import cv2
import numpy as np
from collections import deque, defaultdict
from ultralytics import YOLO
from pathlib import Path
import csv

model = YOLO("/home/debasish/Documents/YOLOv8/weights/pose-weights/yolov8x-832.pt")

input_path = "/home/debasish/Documents/YOLOv8/image052.mp4"
output_base_dir = Path("outputs/reversals")
output_base_dir.mkdir(parents=True, exist_ok=True)

VIDEO_EXTS = [".mp4", ".avi", ".mkv", ".mov"]


# -------------------------
# Create run subfolder
# -------------------------
def create_run_folder(base_dir):
    run_id = 1
    while (base_dir / f"run{run_id}").exists():
        run_id += 1
    run_dir = base_dir / f"run{run_id}"
    run_dir.mkdir(parents=True, exist_ok=True)
    return run_dir

# -------------------------
# Multi-worm video processing using YOLOv8 tracking IDs
# -------------------------
def process_video(video_path, run_dir):
    video_name = Path(video_path).stem
    output_path = run_dir / f"{video_name}_reversals.avi"
    summary_path = run_dir / f"{video_name}_reversals_counted.txt"
    framewise_path = run_dir / f"{video_name}_framewise.csv"

    cap = cv2.VideoCapture(str(video_path))
    width, height = int(cap.get(3)), int(cap.get(4))
    fps = round(cap.get(cv2.CAP_PROP_FPS)) or 30
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(str(output_path), fourcc, fps, (width, height))


    BUFFER_SIZE = int(fps)  # 1-second buffer

    # Per-worm buffers and states keyed by local worm_id (restart per video)
    head_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    tail_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    center_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
    directions = defaultdict(lambda: "Unknown")
    prev_directions = defaultdict(lambda: "Unknown")
    reversal_counts = defaultdict(int)
    first_flags = defaultdict(lambda: True)
    last_reversal_frame = defaultdict(lambda: -int(fps*0.5))

    colors = {}
    def get_color(worm_id):
        if worm_id not in colors:
            np.random.seed(int(worm_id))
            colors[worm_id] = tuple(np.random.randint(0, 255, size=3).tolist())
        return colors[worm_id]

    frame_count = 0
    framewise_data = []

    # Mapping YOLO track IDs to local worm IDs
    yolotrack_to_local = {}
    next_local_id = 0
    all_local_ids = set()

    # Run YOLOv8 tracker on the full video
    results_gen = model.track(str(video_path), persist=True, tracker="bytetrack.yaml")  # generator

    for results in results_gen:
        frame_count += 1
        frame = results.orig_img.copy()
        frame_dict = {"frame": frame_count}

        for result in results:
            if result.keypoints is None or result.boxes is None or result.boxes.id is None:
                continue

            yolotrack_id = int(result.boxes.id.cpu().numpy()[0])
            # Assign a local worm ID if first seen
            if yolotrack_id not in yolotrack_to_local:
                local_id = next_local_id
                yolotrack_to_local[yolotrack_id] = local_id
                next_local_id += 1
            else:
                local_id = yolotrack_to_local[yolotrack_id]

            all_local_ids.add(local_id)

            kpts = result.keypoints.xy.cpu().numpy()[0]
            head = kpts[0]
            tail = kpts[10]
            box = result.boxes.xyxy.cpu().numpy()[0]
            x1, y1, x2, y2 = box
            center = np.array([(x1+x2)/2, (y1+y2)/2])

            # Update buffers
            head_buffers[local_id].append(head)
            tail_buffers[local_id].append(tail)
            center_buffers[local_id].append(center)

            if len(center_buffers[local_id]) < BUFFER_SIZE:
                continue  # wait until buffer fills

            # Compute body vector
            avg_head = np.mean(head_buffers[local_id], axis=0)
            avg_tail = np.mean(tail_buffers[local_id], axis=0)
            body_vec = avg_head - avg_tail
            body_vec /= (np.linalg.norm(body_vec) + 1e-6)

            # Compute movement vector
            move_vec = center_buffers[local_id][-1] - center_buffers[local_id][0]
            move_norm = np.linalg.norm(move_vec)
            if move_norm < 2.0:
                move_vec = np.zeros_like(move_vec)
            else:
                move_vec /= move_norm

            # Hysteresis thresholds
            dot = np.dot(body_vec, move_vec)
            H_FORWARD = 0.3
            H_REVERSE = -0.3
            if dot > H_FORWARD:
                directions[local_id] = "Forward"
            elif dot < H_REVERSE:
                directions[local_id] = "Reverse"
            else:
                directions[local_id] = prev_directions[local_id]

            # Count reversals with cooldown
            if (not first_flags[local_id] and
                prev_directions[local_id] in ["Forward"] and
                directions[local_id] in ["Reverse"] and
                directions[local_id] != prev_directions[local_id] and
                frame_count - last_reversal_frame[local_id] > int(fps*0.5)):

                reversal_counts[local_id] += 1
                last_reversal_frame[local_id] = frame_count

            prev_directions[local_id] = directions[local_id]
            first_flags[local_id] = False

            # Draw vectors and info
            color = get_color(local_id)
            # cv2.arrowedLine(frame, tuple(avg_tail.astype(int)), tuple(avg_head.astype(int)), color, 3, tipLength=0.3)
            cv2.putText(frame,
                        f"ID {local_id} Dir:{directions[local_id]} Rev:{reversal_counts[local_id]}",
                        (int(center[0])+10, int(center[1])+10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2, cv2.LINE_AA)

            # Framewise 0=Forward, 1=Reverse
            frame_dict[f"worm_{local_id}"] = 0 if directions[local_id] == "Forward" else 1

        # Fill missing worms with blank
        for wid in all_local_ids:
            key = f"worm_{wid}"
            if key not in frame_dict:
                frame_dict[key] = ""

        framewise_data.append(frame_dict)
        out.write(frame)

    cap.release()
    out.release()
    cv2.destroyAllWindows()

    # Save summary
    with open(summary_path, "w") as f:
        for wid, count in reversal_counts.items():
            f.write(f"Worm {wid}: {count} reversals\n")

    # Save framewise CSV
    with open(framewise_path, "w", newline="") as csvfile:
        fieldnames = ["frame"] + [f"worm_{wid}" for wid in sorted(all_local_ids)]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in framewise_data:
            writer.writerow(row)

    print(f"[INFO] Video saved at: {output_path}")
    print(f"[INFO] Summary saved at: {summary_path}")
    print(f"[INFO] Framewise CSV saved at: {framewise_path}")


# -------------------------
# Run on single file or folder
# -------------------------
input_path = Path(input_path)

if input_path.is_file() and input_path.suffix.lower() in VIDEO_EXTS:
    run_dir = create_run_folder(output_base_dir)
    process_video(input_path, run_dir)

elif input_path.is_dir():
    videos = [f for f in input_path.iterdir() if f.suffix.lower() in VIDEO_EXTS]
    for v in videos:
        run_dir = create_run_folder(output_base_dir)
        process_video(v, run_dir)
else:
    print(f"[ERROR] No valid video found at {input_path}")
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 2/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 3/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 4/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 5/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 6/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 7/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 8/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 9/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.2ms
# video 1/1 (frame 10/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 11/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 12/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 13/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 14/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 15/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 16/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 17/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 18/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 19/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 20/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 21/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 22/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 23/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.9ms
# video 1/1 (frame 24/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 25/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 26/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 27/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 28/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 29/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 30/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.1ms
# video 1/1 (frame 31/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.5ms
# video 1/1 (frame 32/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.9ms
# video 1/1 (frame 33/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 34/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 22.8ms
# video 1/1 (frame 35/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 36/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 37/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 38/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 39/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 40/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 41/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 42/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 43/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 44/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 45/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 46/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 47/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 48/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 49/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 50/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 51/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 52/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 53/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 54/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.5ms
# video 1/1 (frame 55/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 56/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 57/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 58/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 59/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 60/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.2ms
# video 1/1 (frame 61/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.5ms
# video 1/1 (frame 62/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.0ms
# video 1/1 (frame 63/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.0ms
# video 1/1 (frame 64/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.0ms
# video 1/1 (frame 65/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 27.3ms
# video 1/1 (frame 66/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.5ms
# video 1/1 (frame 67/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.4ms
# video 1/1 (frame 68/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.6ms
# video 1/1 (frame 69/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 70/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 71/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.0ms
# video 1/1 (frame 72/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.4ms
# video 1/1 (frame 73/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 74/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 75/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 76/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 77/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 78/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 79/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 80/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 81/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 82/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 83/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 84/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 85/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 86/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 87/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 88/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 89/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 90/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 91/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.3ms
# video 1/1 (frame 92/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.1ms
# video 1/1 (frame 93/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.1ms
# video 1/1 (frame 94/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.0ms
# video 1/1 (frame 95/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.7ms
# video 1/1 (frame 96/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.8ms
# video 1/1 (frame 97/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.1ms
# video 1/1 (frame 98/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.7ms
# video 1/1 (frame 99/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.8ms
# video 1/1 (frame 100/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.1ms
# video 1/1 (frame 101/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 102/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.1ms
# video 1/1 (frame 103/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 27.4ms
# video 1/1 (frame 104/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.7ms
# video 1/1 (frame 105/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.3ms
# video 1/1 (frame 106/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.6ms
# video 1/1 (frame 107/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.4ms
# video 1/1 (frame 108/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 109/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.4ms
# video 1/1 (frame 110/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.6ms
# video 1/1 (frame 111/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.6ms
# video 1/1 (frame 112/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.1ms
# video 1/1 (frame 113/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.3ms
# video 1/1 (frame 114/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.6ms
# video 1/1 (frame 115/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.3ms
# video 1/1 (frame 116/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.9ms
# video 1/1 (frame 117/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.9ms
# video 1/1 (frame 118/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.5ms
# video 1/1 (frame 119/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.7ms
# video 1/1 (frame 120/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.9ms
# video 1/1 (frame 121/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.4ms
# video 1/1 (frame 122/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.6ms
# video 1/1 (frame 123/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.6ms
# video 1/1 (frame 124/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 125/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.9ms
# video 1/1 (frame 126/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.7ms
# video 1/1 (frame 127/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.7ms
# video 1/1 (frame 128/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.1ms
# video 1/1 (frame 129/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.0ms
# video 1/1 (frame 130/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.8ms
# video 1/1 (frame 131/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.5ms
# video 1/1 (frame 132/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.4ms
# video 1/1 (frame 133/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.1ms
# video 1/1 (frame 134/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.9ms
# video 1/1 (frame 135/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 22.9ms
# video 1/1 (frame 136/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.2ms
# video 1/1 (frame 137/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.9ms
# video 1/1 (frame 138/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 26.2ms
# video 1/1 (frame 139/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 140/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 141/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 142/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 143/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 144/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 145/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 146/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 147/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 148/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.9ms
# video 1/1 (frame 149/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 150/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 151/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 152/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 153/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 154/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 155/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.6ms
# video 1/1 (frame 156/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 157/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 158/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 159/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.4ms
# video 1/1 (frame 160/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 161/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 162/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 163/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 164/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 165/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 166/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 167/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 168/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 169/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 170/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 171/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 172/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 173/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 174/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 175/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 176/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 177/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 178/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 179/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 180/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 181/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 182/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 183/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 184/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 185/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 186/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.7ms
# video 1/1 (frame 187/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 188/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 189/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 190/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 191/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 192/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 193/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 194/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 195/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 196/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 197/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 198/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 199/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 200/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 201/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 202/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 203/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 204/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 28.3ms
# video 1/1 (frame 205/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 206/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 207/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 208/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 209/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 210/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 211/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 212/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 213/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 214/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 215/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 216/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 217/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 218/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 219/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 220/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 221/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 222/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 223/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 224/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 225/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 226/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 227/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 228/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 229/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 230/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.2ms
# video 1/1 (frame 231/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 232/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.1ms
# video 1/1 (frame 233/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 234/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 235/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 236/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 237/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 238/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 239/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 240/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 241/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 242/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 28.2ms
# video 1/1 (frame 243/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 244/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 245/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 246/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 247/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 248/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 249/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 250/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 251/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 252/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 253/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 254/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 255/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 256/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 257/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 258/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 259/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.3ms
# video 1/1 (frame 260/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 261/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 262/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.7ms
# video 1/1 (frame 263/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.1ms
# video 1/1 (frame 264/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 265/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.7ms
# video 1/1 (frame 266/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.4ms
# video 1/1 (frame 267/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 268/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 269/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 270/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 271/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 272/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 273/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 274/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 275/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 276/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.5ms
# video 1/1 (frame 277/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 278/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 279/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 280/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 281/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 282/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 283/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 284/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 285/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 286/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 287/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 288/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 289/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 290/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 291/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 292/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 293/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 294/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 295/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 296/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 297/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 298/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 299/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 300/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 301/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 302/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 303/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 304/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 305/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 306/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 307/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 308/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 309/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 310/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 311/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 312/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 313/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 314/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 315/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 316/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 317/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 318/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 319/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 320/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 321/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 322/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.1ms
# video 1/1 (frame 323/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 324/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 325/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 326/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 327/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.7ms
# video 1/1 (frame 328/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.4ms
# video 1/1 (frame 329/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.4ms
# video 1/1 (frame 330/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.8ms
# video 1/1 (frame 331/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.1ms
# video 1/1 (frame 332/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 26.1ms
# video 1/1 (frame 333/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.1ms
# video 1/1 (frame 334/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.9ms
# video 1/1 (frame 335/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 23.2ms
# video 1/1 (frame 336/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 337/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.5ms
# video 1/1 (frame 338/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.0ms
# video 1/1 (frame 339/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 25.7ms
# video 1/1 (frame 340/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.3ms
# video 1/1 (frame 341/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 9 worms, 24.0ms
# video 1/1 (frame 342/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 343/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 344/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 345/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 346/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 347/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 348/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 349/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 350/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 351/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 352/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 353/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 354/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 355/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 356/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 357/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.1ms
# video 1/1 (frame 358/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 359/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 360/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 361/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 362/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 363/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 364/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 365/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 366/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 367/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 368/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 369/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 370/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 371/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 372/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 373/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 374/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 375/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 376/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 377/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 378/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 379/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 380/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 381/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 382/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 383/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 384/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 385/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.8ms
# video 1/1 (frame 386/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 387/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 388/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 389/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 390/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 391/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 392/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 393/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 394/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 395/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 396/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 397/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 398/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 399/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 400/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 401/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 402/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 403/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 404/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 405/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 406/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 407/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 408/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 409/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 410/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 411/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 412/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 413/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 414/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 415/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 416/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 417/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 418/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.0ms
# video 1/1 (frame 419/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 420/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 421/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 422/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.5ms
# video 1/1 (frame 423/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 424/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.1ms
# video 1/1 (frame 425/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 426/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 29.2ms
# video 1/1 (frame 427/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 428/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 429/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 430/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.4ms
# video 1/1 (frame 431/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 432/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 433/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 434/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 435/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 436/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 437/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 438/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 439/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 440/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 441/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 442/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 443/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 444/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 445/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 446/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 447/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 448/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 449/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 450/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 451/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 452/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 453/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 454/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.1ms
# video 1/1 (frame 455/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 456/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 457/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 458/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 459/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 460/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 461/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 462/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 463/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 464/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 465/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 466/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 467/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 468/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 469/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 470/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 471/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 472/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 473/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 474/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 475/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 476/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 477/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 478/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 479/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 480/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 481/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 482/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 483/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 484/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 485/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 486/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 487/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 488/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 489/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 490/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# ...
# video 1/1 (frame 2875/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 25.5ms
# video 1/1 (frame 2876/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.6ms
# video 1/1 (frame 2877/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.3ms
# video 1/1 (frame 2878/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 24.8ms
# video 1/1 (frame 2879/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 27.5ms
# video 1/1 (frame 2880/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.9ms
# video 1/1 (frame 2881/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.5ms
# video 1/1 (frame 2882/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 26.6ms
# video 1/1 (frame 2883/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.9ms
# video 1/1 (frame 2884/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.8ms
# video 1/1 (frame 2885/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 24.2ms
# video 1/1 (frame 2886/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 27.7ms
# video 1/1 (frame 2887/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.6ms
# video 1/1 (frame 2888/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 23.4ms
# video 1/1 (frame 2889/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 26.6ms
# video 1/1 (frame 2890/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 24.1ms
# video 1/1 (frame 2891/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 27.3ms
# video 1/1 (frame 2892/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 26.1ms
# video 1/1 (frame 2893/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 25.7ms
# video 1/1 (frame 2894/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 25.2ms
# video 1/1 (frame 2895/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 25.0ms
# video 1/1 (frame 2896/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 7 worms, 27.7ms
# video 1/1 (frame 2897/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2898/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 2899/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 2900/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 2901/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2902/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 2903/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 2904/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2905/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 2906/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2907/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 2908/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2909/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 2910/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 2911/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2912/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2913/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2914/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 2915/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 2916/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.8ms
# video 1/1 (frame 2917/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.2ms
# video 1/1 (frame 2918/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 2919/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 2920/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 2921/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.8ms
# video 1/1 (frame 2922/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 2923/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 2924/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 2925/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 2926/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2927/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 2928/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 2929/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 2930/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2931/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.2ms
# video 1/1 (frame 2932/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 2933/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2934/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 2935/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 2936/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2937/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.0ms
# video 1/1 (frame 2938/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.2ms
# video 1/1 (frame 2939/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2940/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 2941/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 2942/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.9ms
# video 1/1 (frame 2943/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2944/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 2945/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 2946/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2947/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2948/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 2949/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 2950/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2951/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 2952/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 2953/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 2954/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.4ms
# video 1/1 (frame 2955/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 29.1ms
# video 1/1 (frame 2956/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 2957/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.3ms
# video 1/1 (frame 2958/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.6ms
# video 1/1 (frame 2959/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.2ms
# video 1/1 (frame 2960/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 2961/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.8ms
# video 1/1 (frame 2962/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 2963/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 22.9ms
# video 1/1 (frame 2964/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 2965/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.3ms
# video 1/1 (frame 2966/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 2967/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2968/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.5ms
# video 1/1 (frame 2969/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2970/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2971/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 2972/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.9ms
# video 1/1 (frame 2973/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2974/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 2975/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.1ms
# video 1/1 (frame 2976/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 2977/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 2978/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2979/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.6ms
# video 1/1 (frame 2980/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2981/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2982/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.9ms
# video 1/1 (frame 2983/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2984/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 2985/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 2986/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.1ms
# video 1/1 (frame 2987/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 2988/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2989/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.8ms
# video 1/1 (frame 2990/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 2991/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 2992/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 2993/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 2994/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 2995/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.7ms
# video 1/1 (frame 2996/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.2ms
# video 1/1 (frame 2997/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 2998/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 2999/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 3000/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 3001/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 3002/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 3003/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.3ms
# video 1/1 (frame 3004/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 3005/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 3006/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.8ms
# video 1/1 (frame 3007/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 3008/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.6ms
# video 1/1 (frame 3009/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.8ms
# video 1/1 (frame 3010/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.8ms
# video 1/1 (frame 3011/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.1ms
# video 1/1 (frame 3012/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.4ms
# video 1/1 (frame 3013/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.7ms
# video 1/1 (frame 3014/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 3015/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.2ms
# video 1/1 (frame 3016/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.1ms
# video 1/1 (frame 3017/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.2ms
# video 1/1 (frame 3018/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 3019/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 3020/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 25.4ms
# video 1/1 (frame 3021/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# video 1/1 (frame 3022/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 3023/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.5ms
# video 1/1 (frame 3024/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 27.4ms
# video 1/1 (frame 3025/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.7ms
# video 1/1 (frame 3026/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.4ms
# video 1/1 (frame 3027/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 26.0ms
# video 1/1 (frame 3028/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.5ms
# video 1/1 (frame 3029/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.3ms
# video 1/1 (frame 3030/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.9ms
# video 1/1 (frame 3031/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 3032/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 24.0ms
# video 1/1 (frame 3033/3034) /home/debasish/Documents/YOLOv8/image052.mp4: 640x832 8 worms, 23.6ms
# Speed: 1.7ms preprocess, 24.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 832)
# [INFO] Video saved at: outputs/reversals/run13/image052_reversals.avi
# [INFO] Summary saved at: outputs/reversals/run13/image052_reversals_counted.txt
# [INFO] Framewise CSV saved at: outputs/reversals/run13/image052_framewise.csv

# %% [raw]
# import cv2
# import numpy as np
# from collections import deque, defaultdict
# from ultralytics import YOLO
# from pathlib import Path
#
# # -------------------------
# # Load YOLOv8 pose model
# # -------------------------
# model = YOLO("/home/debasish/Documents/YOLOv8/weights/pose-weights/yolov8x-832.pt")
#
# # -------------------------
# # Input/Output setup
# # -------------------------
# input_path = "/home/debasish/Documents/YOLOv8/videos/test"  # folder or single video
# output_base_dir = Path("outputs/reversals")
# output_base_dir.mkdir(parents=True, exist_ok=True)
#
# VIDEO_EXTS = [".mp4", ".avi", ".mkv", ".mov"]
#
# # -------------------------
# # Create run subfolder
# # -------------------------
# def create_run_folder(base_dir):
#     run_id = 1
#     while (base_dir / f"run{run_id}").exists():
#         run_id += 1
#     run_dir = base_dir / f"run{run_id}"
#     run_dir.mkdir(parents=True, exist_ok=True)
#     return run_dir
#
# # -------------------------
# # Multi-worm video processing using YOLOv8 tracking IDs
# # -------------------------
# def process_video(video_path, run_dir):
#     video_name = Path(video_path).stem
#     output_path = run_dir / f"{video_name}_reversals.avi"
#     summary_path = run_dir / f"{video_name}_summary.txt"
#
#     cap = cv2.VideoCapture(str(video_path))
#     width, height = int(cap.get(3)), int(cap.get(4))
#     fps = cap.get(cv2.CAP_PROP_FPS)
#     fourcc = cv2.VideoWriter_fourcc(*"XVID")
#     out = cv2.VideoWriter(str(output_path), fourcc, fps, (width, height))
#
#     BUFFER_SIZE = int(fps)  # 1-second buffer
#
#     # Per-worm buffers and states keyed by YOLO track_id
#     head_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
#     tail_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
#     center_buffers = defaultdict(lambda: deque(maxlen=BUFFER_SIZE))
#     directions = defaultdict(lambda: "Unknown")
#     prev_directions = defaultdict(lambda: "Unknown")
#     reversal_counts = defaultdict(int)
#     first_flags = defaultdict(lambda: True)
#     last_reversal_frame = defaultdict(lambda: -int(fps*0.5))
#
#     colors = {}
#     def get_color(worm_id):
#         if worm_id not in colors:
#             np.random.seed(int(worm_id))
#             colors[worm_id] = tuple(np.random.randint(0, 255, size=3).tolist())
#         return colors[worm_id]
#
#     frame_count = 0
#
#     # Run YOLOv8 tracker on the full video
#     results_gen = model.track(str(video_path), persist=True, tracker="bytetrack.yaml")  # generator
#
#     for results in results_gen:
#         frame_count += 1
#         frame = results.orig_img.copy()
#
#         for result in results:
#             if result.keypoints is None or result.boxes is None or result.boxes.id is None:
#                 continue
#
#             track_id = int(result.boxes.id.cpu().numpy()[0])
#             kpts = result.keypoints.xy.cpu().numpy()[0]
#             head = kpts[0]
#             tail = kpts[10]
#             box = result.boxes.xyxy.cpu().numpy()[0]
#             x1, y1, x2, y2 = box
#             center = np.array([(x1+x2)/2, (y1+y2)/2])
#
#             # Update buffers
#             head_buffers[track_id].append(head)
#             tail_buffers[track_id].append(tail)
#             center_buffers[track_id].append(center)
#
#             if len(center_buffers[track_id]) < BUFFER_SIZE:
#                 continue  # wait until buffer fills
#
#             # Compute body vector
#             avg_head = np.mean(head_buffers[track_id], axis=0)
#             avg_tail = np.mean(tail_buffers[track_id], axis=0)
#             body_vec = avg_head - avg_tail
#             body_vec /= (np.linalg.norm(body_vec) + 1e-6)
#
#             # Compute movement vector
#             move_vec = center_buffers[track_id][-1] - center_buffers[track_id][0]
#             move_norm = np.linalg.norm(move_vec)
#             if move_norm < 2.0:  # ignore tiny movements
#                 move_vec = np.zeros_like(move_vec)
#             else:
#                 move_vec /= move_norm
#
#             # Hysteresis thresholds for direction
#             dot = np.dot(body_vec, move_vec)
#             H_FORWARD = 0.5
#             H_REVERSE = -0.5
#             if dot > H_FORWARD:
#                 directions[track_id] = "Forward"
#             elif dot < H_REVERSE:
#                 directions[track_id] = "Reverse"
#             else:
#                 directions[track_id] = prev_directions[track_id]
#
#             # Count reversal if direction flips and cooldown passed
#             if (not first_flags[track_id] and
#                 prev_directions[track_id] in ["Forward","Reverse"] and
#                 directions[track_id] in ["Forward","Reverse"] and
#                 directions[track_id] != prev_directions[track_id] and
#                 frame_count - last_reversal_frame[track_id] > int(fps*0.5)):
#
#                 reversal_counts[track_id] += 1
#                 last_reversal_frame[track_id] = frame_count
#
#             prev_directions[track_id] = directions[track_id]
#             first_flags[track_id] = False
#
#             # Draw vectors and info
#             color = get_color(track_id)
#             cv2.arrowedLine(frame, tuple(avg_tail.astype(int)), tuple(avg_head.astype(int)), color, 3, tipLength=0.3)
#             cv2.putText(frame,
#                         f"ID {track_id} Dir:{directions[track_id]} Rev:{reversal_counts[track_id]}",
#                         (int(center[0])+10, int(center[1])+10),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2, cv2.LINE_AA)
#
#         out.write(frame)
#
#     cap.release()
#     out.release()
#     cv2.destroyAllWindows()
#
#     # Save summary
#     with open(summary_path, "w") as f:
#         for wid, count in reversal_counts.items():
#             f.write(f"Worm {wid}: {count} reversals\n")
#
#     print(f"[INFO] Video saved at: {output_path}")
#     print(f"[INFO] Summary saved at: {summary_path}")
#
#
# # -------------------------
# # Run on single file or folder
# # -------------------------
# input_path = Path(input_path)
#
# if input_path.is_file() and input_path.suffix.lower() in VIDEO_EXTS:
#     run_dir = create_run_folder(output_base_dir)
#     process_video(input_path, run_dir)
#
# elif input_path.is_dir():
#     videos = [f for f in input_path.iterdir() if f.suffix.lower() in VIDEO_EXTS]
#     for v in videos:
#         run_dir = create_run_folder(output_base_dir)
#         process_video(v, run_dir)
# else:
#     print(f"[ERROR] No valid video found at {input_path}")
